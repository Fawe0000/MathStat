# %% [markdown]
# # Харьковцов А.В. Теория вероятностей и математическая статистика ДЗ_4

# %% [markdown]
# # Задача 1

# %% [markdown]
# Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.
#
# $$Решение: $$
#
# $$M(X) = \frac{a + b}{2} = \frac{200 + 800}{2}=  500; $$
#
# $$D(X) = \frac{(b - a)^2}{12} = \frac{(800 - 200)^2}{12}=30'000; $$
#
# $$\sigma = \sqrt{D(X)} \approx173.21 $$

# %% [markdown]
# # Задача 2

# %% [markdown]
# О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# Если да, найдите ее.
#
# $Решение: $
#
# $$D(X) = 0.2 = \frac{(b - 0.5)^2}{12} =>$$
#
#
# $$2.4 = (b - 0.5)^2 => $$
#
#
# $$b\approx2.05 $$

# %% [markdown]
# # Задача 3

# %% [markdown]
# Непрерывная случайная величина X распределена нормально и задана плотностью распределения
# f(x) = (1 / (4 * sqrt(2*pi))) * (exp(-((x+2)**2) / 32))
#
# Найдите:
#
# а) M(X)
#
# б) D(X)
#
# в) std(X) (среднее квадратичное отклонение)
#
# $Решение:$
# $$f(x) = \frac{1}{\sigma \sqrt{2 \pi}} e ^ {- \frac{(x - a)^2}{2 \sigma^2}},$$
# где $a = M(X), \; \sigma^2 = D(X).$
#
# Таким образом, в задаче:
#
# $\sigma = std(X) = 4,$
#
# $a = M(X) = -2,$
#
# $\sigma^2 = D(X) = 16.$

# %% [markdown]
# # Задача 4

# %% [markdown]
# Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
#
# а) больше 182 см
#
# б) больше 190 см
#
# в) от 166 см до 190 см
#
# г) от 166 см до 182 см
#
# д) от 158 см до 190 см
#
# е) не выше 150 см или не ниже 190 см
#
# ё) не выше 150 см или не ниже 198 см
#
# ж) ниже 166 см.
#
# $Решение:$
# $$f(x) = \frac{1}{\sigma \sqrt{2 \pi}} e ^ {- \frac{(x - a)^2}{2 \sigma^2}},$$
# где $a = M(X) = 174, \; \sigma = 8.$
#
# Рассчитаем Z по формуле:
# Z = (X - 174)/8
#
# Значение вероятности определим по таблице.
#
# вероятность, что случайный человек больше 182 см = $15,87 \% $
#
# вероятность, что случайный человек больше 190 см = $2,28\%$
#
# вероятность, что случайный человек от 166 см до 190 см = $81,86\%$
#
# вероятность, что случайный человек от 166 см до 182 см = $68,28\% $
#
# вероятность, что случайный человек от 158 см до 190 см = $95,45\% $
#
# вероятность, что случайный человек не выше 150 см или не ниже 190 см = 0,135% + 2,275% =$ 2,41\% $
#
# вероятность, что случайный человек не выше 150 см или не ниже 198 см = 0,135% + 0,135% =$ 0,27\% $
#
# вероятность, что случайный человек больше 166 см = $15,87\% $

# %% [markdown]
# # Задача 5

# %% [markdown]
# На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?
#
#
# $Решение: $
#
#
# $\sigma = \sqrt{D(X)} = 5 см $
#
# Рост человека, равный 190 см, отглоняется от математического ожидания роста в популяции на:
#
# $ \frac{X - M(X)}{\sigma} = \frac{190 - 178}{5}  = 2.4 $
