# %% [markdown]
# ##### Харьковцов А.В. Теория вероятностей и математическая статистика ДЗ_5

# %%
import numpy as np
from math import factorial

# Формула числа сочетаний`
def combinations(n, k):
    return int(factorial(n) / (factorial(k) * factorial(n - k)))

# %% [markdown]
# # Задача 1

# %% [markdown]
# 1.Известно, что генеральная совокупность распределена нормально со средним квадратическим отклонением, равным 16.
#
# Найти доверительный интервал для оценки математического ожидания с надежностью 0.95, если выборочная средняя M = 80, а объем выборки n = 256.
#
# $Решение: $
#
# $$M \pm Z_{\alpha/2} \cdot\frac{\sigma}{\sqrt{n}} $$
#
# $80 \pm Z_{(1-0.95)/2} \cdot\frac{16}{\sqrt{256}} $
#
# $80 \pm 1.96 \cdot\frac{16}{16} $
#
# $[78.04; 81.96] $

# %% [markdown]
# # Задача 2

# %% [markdown]
# В результате 10 независимых измерений некоторой величины X, выполненных с одинаковой точностью, получены опытные данные:
#
# 6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1
#
# Предполагая, что результаты измерений подчинены нормальному закону распределения вероятностей, оценить истинное значение величины X при помощи доверительного интервала, покрывающего это значение с доверительной вероятностью 0,95
#
# $Решение: $
# т.к. среднее квадратическое отклонение генеральной совокупности нам неизвестно, воспользуемся формулой:
#
# $$T_{1,2} = \overline{X} \pm t_{v,\alpha/2} \cdot\frac{\sigma}{\sqrt{n}} $$
#
# Среднее выборочное: 6.59
#
# Среднее квадратичное отклонение: 0.45
#
# Доверительный интервал с вероятностью 95%: [6.27, 6.91]

# %%
# Решение:
zp_v=np.array([6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1])
n=len(zp_v)
zp_v.sort()
m = zp_v.sum()/n
print (f"Среднее выборочное: {m:.2f}")
s = (((zp_v-m)**2).sum()/(n-1))**.5
print (f"Среднее квадратичное отклонение: {s:.2f}")
print (f"Доверительный интервал с вероятностью 95%: [{m-2.262*s/10**0.5:.2f}, {m+2.262*s/10**0.5:.2f}]")
# Out:
# Среднее выборочное: 6.59
# Среднее квадратичное отклонение: 0.45
# Доверительный интервал с вероятностью 95%: [6.27, 6.91]

# %% [markdown]
# # Задача 3

# %% [markdown]
# Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм.
# Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр оказался равным 17.5 мм, а дисперсия известна и равна 4 кв.мм.
#
# $Решение:$
#
# $$Z_{H} = \frac{\overline{X} - \mu_0} {\sigma/\sqrt{n}} $$
#
# α= 0,05  = >  P(Zн > Z )
#
# Zн = (17,5 - 17) / 2/10 = 2.5
#
# Z  = 1,654
#
# Н0 верна

# %% [markdown]
# # Задача 4

# %% [markdown]
# Продавец утверждает, что средний вес пачки печенья составляет 200 г. Из партии извлечена выборка из 10 пачек.
# Вес каждой пачки составляет:
# 202, 203, 199, 197, 195, 201, 200, 204, 194, 190. Известно,что их веса распределены нормально.
#
# Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%?
#
# $Решение:$
# α= 0,01
#
# Среднее выборочное: 198.50 < 200 = >  P(tн < t )
#
# tн = 1.010
#
# t  = 3.250 (по таблице при v = 9 и α= 0.005)
#
# tн < t => утверждение продавца - $верно$

# %%
# Решение:
zp_v=np.array([202, 203, 199, 197, 195, 201, 200, 204, 194, 190])
n=len(zp_v)
zp_v.sort()
m = zp_v.sum()/n
print (f"Среднее выборочное: {m:.2f}")
s = (((zp_v-m)**2).sum()/(n-1))**.5
print (f"Среднее квадратичное отклонение: {s:.2f}")
print (f"t для выборки составит: {abs((m-200)/s*(n-1)**0.5):.3f}")
# Out:
# Среднее выборочное: 198.50
# Среднее квадратичное отклонение: 4.45
# t для выборки составит: 1.010
